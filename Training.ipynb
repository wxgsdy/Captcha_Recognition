# %%
import os
import tensorflow as tf
from PIL import Image
from nets import nets_factory   
import numpy as np

# %%
CAHR_SET_LEN = 10
IMAGE_HEIGHT, IMAGE_WIDTH = 60, 100
BATCH_SIZE = 25 
TFRECORD_FILE = 'captcha/train.tfrecords'

x = tf.placeholder(tf.float32,[None,224,224])
y0 = tf.placeholder(tf.float32,[None])
y1 = tf.placeholder(tf.float32,[None])
y2 = tf.placeholder(tf.float32,[None])
y3 = tf.placeholder(tf.float32,[None])

lr = tf.Variable(0.003, dtype = tf.float32)

def read_and_decode(filename):
    filename_queue = tf.train.string_input_producer([filename])
    reader = tf.TFRecordReader()
    
    # get filenames(labels)
    _, serialized_example = reader.read(filename_queue)
    features = tf.parse_single_example(serialized_example,
                                      features = {
                                      'image': tf.FixedLenFeature([],tf.string),
                                      'label0': tf.FixedLenFeature([],tf.int64),
                                      'label1': tf.FixedLenFeature([],tf.int64),
                                      'label2': tf.FixedLenFeature([],tf.int64),
                                      'label3': tf.FixedLenFeature([],tf.int64) 
                                 })
    
    
    image = tf.decode_raw(features['image'],tf.uint8)
    
      
    image = tf.reshape(image,[224,224])    
    image = tf.cast(image,tf.float32) / 255.0
    image = tf.subtract(image,0.5)
    image = tf.multiply(image,2.0)
    
    label0 = tf.cast(features['label0'],tf.int32)
    label1 = tf.cast(features['label1'],tf.int32)
    label2 = tf.cast(features['label2'],tf.int32)
    label3 = tf.cast(features['label3'],tf.int32)

    return image, label0, label1, label2, label3

# %%
image, label0, label1, label2, label3 = read_and_decode(TFRECORD_FILE)

# divide batches(shuffle)
image_batch, label_batch0, label_batch1, label_batch2, label_batch3 = tf.train.shuffle_batch(
        [image, label0, label1,label2,label3], batch_size = BATCH_SIZE,
        capacity = 50000, min_after_dequeue = 10000, num_threads = 1)

train_network_fn = nets_factory.get_network_fn(
    'alexnet_v2',
    num_classes = CAHR_SET_LEN,
    weight_decay = 0.0005,
    is_training = True)

with tf.Session() as sess:    

    #inputs: a tensor of size[batch_size, height, width,channels]
    
    X = tf.reshape(x,[BATCH_SIZE, 224, 224, 1])
    
    # forward pass 
    logits0, logits1, logits2, logits3, end_points = train_network_fn(X)

    # one-hot encoder
    one_hot_labels0 = tf.one_hot(indices = tf.cast(y0,tf.int32), depth = CAHR_SET_LEN)
    one_hot_labels1 = tf.one_hot(indices = tf.cast(y1,tf.int32), depth = CAHR_SET_LEN)
    one_hot_labels2 = tf.one_hot(indices = tf.cast(y2,tf.int32), depth = CAHR_SET_LEN)
    one_hot_labels3 = tf.one_hot(indices = tf.cast(y3,tf.int32), depth = CAHR_SET_LEN)

    # compute loss
    loss0 = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits = logits0, labels = one_hot_labels0))
    loss1 = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits = logits1, labels = one_hot_labels1))
    loss2 = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits = logits2, labels = one_hot_labels2))
    loss3 = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits = logits3, labels = one_hot_labels3))    
    total_loss = (loss0 + loss1 + loss2 + loss3) / 4.0

    # define optimizer
    optimizer = tf.train.AdamOptimizer(learning_rate = lr).minimize(total_loss)

    # accuracy
    correct_prediction0 = tf.equal(tf.argmax(one_hot_labels0, 1), tf.argmax(logits0, 1))
    accuracy0 = tf.reduce_mean(tf.cast(correct_prediction0, tf.float32))

    correct_prediction1 = tf.equal(tf.argmax(one_hot_labels1, 1), tf.argmax(logits1, 1))
    accuracy1 = tf.reduce_mean(tf.cast(correct_prediction1, tf.float32))

    correct_prediction2 = tf.equal(tf.argmax(one_hot_labels2, 1), tf.argmax(logits2, 1))
    accuracy2 = tf.reduce_mean(tf.cast(correct_prediction2, tf.float32))

    correct_prediction3 = tf.equal(tf.argmax(one_hot_labels3, 1), tf.argmax(logits3, 1))
    accuracy3 = tf.reduce_mean(tf.cast(correct_prediction3, tf.float32))

    losses = []
    accs0, accs1,accs2,accs3 = [],[],[],[]
    # init training 
    saver = tf.train.Saver()
    sess.run(tf.global_variables_initializer())    
    coord = tf.train.Coordinator()     # create coordinator for threads management   
    threads = tf.train.start_queue_runners(sess = sess, coord = coord)

    for i in range(2001):        
        b_image, b_label0, b_label1, b_label2, b_label3 = sess.run([image_batch, label_batch0, label_batch1, label_batch2, label_batch3])        
        
        sess.run(optimizer, feed_dict = {x:b_image, y0: b_label0, y1:b_label1, y2:b_label2, y3:b_label3})
        
        if i % 20 == 0:
            if i % 2000 == 0:
                sess.run(tf.assign(lr, lr/3))
            acc0, acc1, acc2, acc3, loss_ = sess.run([accuracy0,accuracy1,accuracy2,accuracy3, total_loss], feed_dict = {x:b_image, y0: b_label0, y1:b_label1, y2:b_label2, y3:b_label3})
            learning_rate = sess.run(lr)
            print("Iter: %d Loss:%.3f  Accuracy:%.2f, %.2f, %.2f, %.2f Learning Rate: %.4f" % (i, loss_, acc0, acc1,acc2,acc3, learning_rate))
            losses.append(loss_)
            accs0.append(acc0)
            accs1.append(acc1)
            accs2.append(acc2)
            accs3.append(acc3)
            
            if i == 2000:
                saver.save(sess,'./captcha/models/crack_captcha.model', global_step = i)
                break 
                
    coord.request_stop()    
    coord.join(threads)
# Out:
# Iter: 0 Loss:2949.960  Accuracy:0.20, 0.20, 0.20, 0.20 Learning Rate: 0.0010
# Iter: 20 Loss:2.230  Accuracy:0.24, 0.24, 0.24, 0.24 Learning Rate: 0.0010
# Iter: 40 Loss:2.360  Accuracy:0.00, 0.04, 0.00, 0.00 Learning Rate: 0.0010
# Iter: 60 Loss:2.311  Accuracy:0.04, 0.12, 0.04, 0.08 Learning Rate: 0.0010
# Iter: 80 Loss:2.309  Accuracy:0.16, 0.12, 0.12, 0.08 Learning Rate: 0.0010
# Iter: 100 Loss:2.304  Accuracy:0.12, 0.12, 0.12, 0.12 Learning Rate: 0.0010
# Iter: 120 Loss:2.326  Accuracy:0.00, 0.00, 0.00, 0.00 Learning Rate: 0.0010
# Iter: 140 Loss:2.376  Accuracy:0.08, 0.04, 0.12, 0.12 Learning Rate: 0.0010
# Iter: 160 Loss:2.314  Accuracy:0.04, 0.04, 0.04, 0.04 Learning Rate: 0.0010
# Iter: 180 Loss:2.080  Accuracy:0.08, 0.12, 0.12, 0.12 Learning Rate: 0.0010
# Iter: 200 Loss:1.616  Accuracy:0.48, 0.52, 0.48, 0.52 Learning Rate: 0.0010
# Iter: 220 Loss:1.683  Accuracy:0.40, 0.36, 0.44, 0.44 Learning Rate: 0.0010
# Iter: 240 Loss:1.157  Accuracy:0.52, 0.48, 0.52, 0.52 Learning Rate: 0.0010
# Iter: 260 Loss:1.264  Accuracy:0.52, 0.56, 0.52, 0.52 Learning Rate: 0.0010
# Iter: 280 Loss:1.343  Accuracy:0.44, 0.44, 0.36, 0.40 Learning Rate: 0.0010
# Iter: 300 Loss:1.016  Accuracy:0.60, 0.68, 0.64, 0.64 Learning Rate: 0.0010
# Iter: 320 Loss:1.462  Accuracy:0.44, 0.44, 0.48, 0.48 Learning Rate: 0.0010
# Iter: 340 Loss:0.724  Accuracy:0.76, 0.72, 0.72, 0.68 Learning Rate: 0.0010
# Iter: 360 Loss:0.750  Accuracy:0.80, 0.84, 0.80, 0.84 Learning Rate: 0.0010
# Iter: 380 Loss:0.658  Accuracy:0.76, 0.76, 0.76, 0.76 Learning Rate: 0.0010
# Iter: 400 Loss:0.751  Accuracy:0.72, 0.72, 0.72, 0.72 Learning Rate: 0.0010
# Iter: 420 Loss:0.347  Accuracy:0.88, 0.88, 0.88, 0.92 Learning Rate: 0.0010
# Iter: 440 Loss:0.356  Accuracy:0.88, 0.84, 0.84, 0.84 Learning Rate: 0.0010
# Iter: 460 Loss:0.164  Accuracy:0.96, 0.96, 0.96, 0.96 Learning Rate: 0.0010
# Iter: 480 Loss:0.476  Accuracy:0.84, 0.84, 0.84, 0.84 Learning Rate: 0.0010
# Iter: 500 Loss:0.507  Accuracy:0.80, 0.80, 0.80, 0.76 Learning Rate: 0.0010
# Iter: 520 Loss:0.324  Accuracy:0.88, 0.84, 0.84, 0.88 Learning Rate: 0.0010
# Iter: 540 Loss:0.459  Accuracy:0.88, 0.88, 0.88, 0.88 Learning Rate: 0.0010
# Iter: 560 Loss:0.539  Accuracy:0.80, 0.80, 0.80, 0.80 Learning Rate: 0.0010
# Iter: 580 Loss:0.105  Accuracy:0.96, 0.96, 0.96, 0.96 Learning Rate: 0.0010
# Iter: 600 Loss:0.272  Accuracy:0.84, 0.84, 0.84, 0.84 Learning Rate: 0.0010
# Iter: 620 Loss:0.220  Accuracy:0.92, 0.92, 0.92, 0.92 Learning Rate: 0.0010
# Iter: 640 Loss:0.276  Accuracy:0.88, 0.88, 0.88, 0.88 Learning Rate: 0.0010
# Iter: 660 Loss:0.182  Accuracy:0.96, 0.96, 0.92, 0.92 Learning Rate: 0.0010
# Iter: 680 Loss:0.203  Accuracy:0.92, 0.92, 0.92, 0.92 Learning Rate: 0.0010
# Iter: 700 Loss:0.161  Accuracy:0.96, 0.96, 0.96, 0.96 Learning Rate: 0.0010
# Iter: 720 Loss:0.210  Accuracy:0.92, 0.92, 0.92, 0.92 Learning Rate: 0.0010
# Iter: 740 Loss:0.221  Accuracy:0.92, 0.92, 0.92, 0.92 Learning Rate: 0.0010
# Iter: 760 Loss:0.345  Accuracy:0.84, 0.84, 0.84, 0.84 Learning Rate: 0.0010
# Iter: 780 Loss:0.046  Accuracy:1.00, 1.00, 1.00, 1.00 Learning Rate: 0.0010
# Iter: 800 Loss:0.143  Accuracy:0.96, 0.96, 0.96, 0.96 Learning Rate: 0.0010
# Iter: 820 Loss:0.176  Accuracy:0.92, 0.92, 0.92, 0.92 Learning Rate: 0.0010
# Iter: 840 Loss:0.189  Accuracy:0.96, 0.96, 0.96, 0.96 Learning Rate: 0.0010
# Iter: 860 Loss:0.227  Accuracy:0.96, 0.96, 0.96, 0.96 Learning Rate: 0.0010
# Iter: 880 Loss:0.073  Accuracy:1.00, 1.00, 1.00, 1.00 Learning Rate: 0.0010
# Iter: 900 Loss:0.095  Accuracy:1.00, 1.00, 0.96, 1.00 Learning Rate: 0.0010
# Iter: 920 Loss:0.098  Accuracy:0.96, 0.96, 0.96, 0.96 Learning Rate: 0.0010
# Iter: 940 Loss:0.142  Accuracy:0.96, 0.92, 0.92, 0.92 Learning Rate: 0.0010
# Iter: 960 Loss:0.006  Accuracy:1.00, 1.00, 1.00, 1.00 Learning Rate: 0.0010
# Iter: 980 Loss:0.164  Accuracy:0.96, 0.96, 0.96, 0.96 Learning Rate: 0.0010
# Iter: 1000 Loss:0.009  Accuracy:1.00, 1.00, 1.00, 1.00 Learning Rate: 0.0010
# Iter: 1020 Loss:0.175  Accuracy:0.96, 0.96, 0.96, 0.96 Learning Rate: 0.0010
# Iter: 1040 Loss:0.015  Accuracy:1.00, 1.00, 1.00, 1.00 Learning Rate: 0.0010
# Iter: 1060 Loss:0.123  Accuracy:0.92, 0.92, 0.92, 0.92 Learning Rate: 0.0010
# Iter: 1080 Loss:0.084  Accuracy:0.96, 0.96, 0.96, 0.96 Learning Rate: 0.0010
# Iter: 1100 Loss:0.383  Accuracy:0.88, 0.88, 0.88, 0.88 Learning Rate: 0.0010
# Iter: 1120 Loss:0.010  Accuracy:1.00, 1.00, 1.00, 1.00 Learning Rate: 0.0010
# Iter: 1140 Loss:0.129  Accuracy:0.96, 0.96, 0.96, 0.96 Learning Rate: 0.0010
# Iter: 1160 Loss:0.087  Accuracy:0.96, 0.96, 0.96, 0.96 Learning Rate: 0.0010
# Iter: 1180 Loss:0.086  Accuracy:0.96, 0.96, 0.96, 0.96 Learning Rate: 0.0010
# Iter: 1200 Loss:0.035  Accuracy:1.00, 1.00, 1.00, 1.00 Learning Rate: 0.0010
# Iter: 1220 Loss:0.035  Accuracy:1.00, 1.00, 1.00, 1.00 Learning Rate: 0.0010
# Iter: 1240 Loss:0.067  Accuracy:0.96, 0.96, 0.96, 0.96 Learning Rate: 0.0010
# Iter: 1260 Loss:0.054  Accuracy:1.00, 1.00, 1.00, 1.00 Learning Rate: 0.0010
# Iter: 1280 Loss:0.007  Accuracy:1.00, 1.00, 1.00, 1.00 Learning Rate: 0.0010
# Iter: 1300 Loss:0.005  Accuracy:1.00, 1.00, 1.00, 1.00 Learning Rate: 0.0010
# Iter: 1320 Loss:0.074  Accuracy:0.96, 1.00, 1.00, 0.96 Learning Rate: 0.0010
# Iter: 1340 Loss:0.121  Accuracy:0.96, 0.96, 0.96, 0.96 Learning Rate: 0.0010
# Iter: 1360 Loss:0.014  Accuracy:1.00, 1.00, 1.00, 1.00 Learning Rate: 0.0010
# Iter: 1380 Loss:0.062  Accuracy:1.00, 1.00, 1.00, 1.00 Learning Rate: 0.0010
# Iter: 1400 Loss:0.102  Accuracy:0.96, 0.96, 0.96, 0.96 Learning Rate: 0.0010
# Iter: 1420 Loss:0.033  Accuracy:1.00, 1.00, 1.00, 1.00 Learning Rate: 0.0010
# Iter: 1440 Loss:0.000  Accuracy:1.00, 1.00, 1.00, 1.00 Learning Rate: 0.0010
# Iter: 1460 Loss:0.070  Accuracy:0.96, 1.00, 1.00, 1.00 Learning Rate: 0.0010
# Iter: 1480 Loss:0.013  Accuracy:1.00, 1.00, 1.00, 1.00 Learning Rate: 0.0010
# Iter: 1500 Loss:0.141  Accuracy:0.96, 0.96, 0.96, 0.96 Learning Rate: 0.0010
# Iter: 1520 Loss:0.007  Accuracy:1.00, 1.00, 1.00, 1.00 Learning Rate: 0.0010
# Iter: 1540 Loss:0.072  Accuracy:1.00, 0.96, 1.00, 1.00 Learning Rate: 0.0010
# Iter: 1560 Loss:0.013  Accuracy:1.00, 1.00, 1.00, 1.00 Learning Rate: 0.0010
# Iter: 1580 Loss:0.040  Accuracy:0.96, 0.96, 0.96, 0.96 Learning Rate: 0.0010
# Iter: 1600 Loss:0.016  Accuracy:1.00, 1.00, 1.00, 1.00 Learning Rate: 0.0010
# Iter: 1620 Loss:0.005  Accuracy:1.00, 1.00, 1.00, 1.00 Learning Rate: 0.0010
# Iter: 1640 Loss:0.053  Accuracy:1.00, 1.00, 1.00, 1.00 Learning Rate: 0.0010
# Iter: 1660 Loss:0.023  Accuracy:1.00, 1.00, 1.00, 1.00 Learning Rate: 0.0010
# Iter: 1680 Loss:0.138  Accuracy:0.96, 0.96, 0.96, 0.96 Learning Rate: 0.0010
# Iter: 1700 Loss:0.012  Accuracy:1.00, 1.00, 1.00, 1.00 Learning Rate: 0.0010
# Iter: 1720 Loss:0.103  Accuracy:0.96, 0.96, 0.96, 0.96 Learning Rate: 0.0010
# Iter: 1740 Loss:0.095  Accuracy:0.96, 0.96, 0.96, 0.96 Learning Rate: 0.0010
# Iter: 1760 Loss:0.005  Accuracy:1.00, 1.00, 1.00, 1.00 Learning Rate: 0.0010
# Iter: 1780 Loss:0.069  Accuracy:0.96, 0.96, 0.96, 0.96 Learning Rate: 0.0010
# Iter: 1800 Loss:0.015  Accuracy:1.00, 1.00, 1.00, 1.00 Learning Rate: 0.0010
# Iter: 1820 Loss:0.054  Accuracy:1.00, 1.00, 1.00, 1.00 Learning Rate: 0.0010
# Iter: 1840 Loss:0.045  Accuracy:1.00, 1.00, 1.00, 1.00 Learning Rate: 0.0010
# Iter: 1860 Loss:0.019  Accuracy:1.00, 1.00, 1.00, 1.00 Learning Rate: 0.0010
# Iter: 1880 Loss:0.034  Accuracy:1.00, 1.00, 1.00, 1.00 Learning Rate: 0.0010
# Iter: 1900 Loss:0.065  Accuracy:1.00, 0.96, 0.96, 1.00 Learning Rate: 0.0010
# Iter: 1920 Loss:0.049  Accuracy:0.96, 0.96, 0.96, 1.00 Learning Rate: 0.0010
# Iter: 1940 Loss:0.193  Accuracy:0.92, 0.92, 0.92, 0.92 Learning Rate: 0.0010
# Iter: 1960 Loss:0.032  Accuracy:1.00, 1.00, 1.00, 1.00 Learning Rate: 0.0010
# Iter: 1980 Loss:0.019  Accuracy:1.00, 1.00, 1.00, 1.00 Learning Rate: 0.0010
# Iter: 2000 Loss:0.045  Accuracy:1.00, 1.00, 1.00, 0.96 Learning Rate: 0.0003

# %%
#losses = []
#accs0, accs1,accs2,accs3 = [],[],[],[]
tt = losses[1:]
print(tt)
# Out:
# [2.2301197, 2.3598547, 2.311077, 2.308581, 2.3039365, 2.3258529, 2.3757904, 2.3141198, 2.0795307, 1.6164591, 1.6834997, 1.1568704, 1.2635951, 1.3433212, 1.0159931, 1.462353, 0.7240821, 0.7499572, 0.6581744, 0.75148535, 0.34728032, 0.35577905, 0.16424255, 0.47629935, 0.5071932, 0.3238995, 0.45924917, 0.5391009, 0.10538639, 0.27202177, 0.21952295, 0.27579415, 0.18184032, 0.20268415, 0.16081731, 0.21043475, 0.22090477, 0.34460354, 0.04619245, 0.14293008, 0.17554651, 0.18855599, 0.22666007, 0.07282446, 0.09476331, 0.09840326, 0.14233541, 0.0063199783, 0.16387086, 0.0091770105, 0.17466061, 0.014508199, 0.12279827, 0.08419081, 0.38340926, 0.010240983, 0.1285661, 0.08673972, 0.086084604, 0.03494567, 0.03544248, 0.06691845, 0.05435751, 0.0068038944, 0.004939341, 0.0737756, 0.12086514, 0.01397849, 0.062012076, 0.102192916, 0.032653213, 0.00039007762, 0.06975507, 0.012588463, 0.14128643, 0.0073304917, 0.07192111, 0.013116747, 0.03987263, 0.015843939, 0.005467127, 0.052928098, 0.022511542, 0.1375058, 0.012473395, 0.102642134, 0.09485326, 0.0048435703, 0.069296785, 0.015282025, 0.053886347, 0.044665024, 0.018872645, 0.03401247, 0.065043285, 0.049251854, 0.19297887, 0.031976163, 0.019110698, 0.045412682]

# %%
import matplotlib.pyplot as plt

def plot_accuracy(): 
    fig,ax = plt.subplots()     
    plt.xlabel('Training epochs')  
    plt.ylabel('Accuracy') 
    x = range(len(accs0))
    #ax.set_ylim([0,0.8])  
    #ax.set_xlim([58,42])
    ax.plot(x,accs0,'g',label = 'digit-1')    
    ax.plot(x,accs1,'y',label = 'digit-2')
    ax.plot(x,accs2,'r',label = 'digit-3')
    ax.plot(x,accs3,'b',label = 'digit-4')
    plt.grid(True)  
    plt.legend(bbox_to_anchor=(1.0, 0), loc = 4, borderaxespad=0.)  
    plt.show()  
    
    
def plot_loss():
    fig,ax = plt.subplots()     
    plt.xlabel('Training epochs')  
    plt.ylabel('Loss values') 
    x = range(len(tt))
    #ax.set_ylim([0,1])  
    #ax.set_xlim([58,42])
    ax.plot(x,tt,'g',label = 'train set')    
    #ax.plot(x,loss_test,'r',label = 'test set') 
    #ax.plot(x,loss_val,'y',label = 'validation set')
    plt.grid(True)  
    plt.legend(bbox_to_anchor=(1.0, 1.0), loc = 1, borderaxespad=0.)  
    plt.show()

# %%
plot_accuracy()
plot_loss()
